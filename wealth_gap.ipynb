# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
wealth_gap_df = pd.read_csv("./resources-jc/networth_table_clean.csv")
wealth_gap_df.set_index('Year (Q4)', inplace=True)
wealth_gap_df = wealth_gap_df.drop(['Unnamed: 5', 'Unnamed: 6'], axis=1)
wealth_gap_df.head(50)
# Out:
#             BabyBoom      GenX  Millennial     Silent
# Year (Q4)
# 1989         59642.0    1806.0         0.0   208044.0
# 1990         61561.0    2423.0         0.0   215243.0
# 1991         69911.0    3534.0         0.0   231121.0
# 1992         78361.0    4619.0         0.0   241286.0
# 1993         88424.0    7119.0         0.0   253392.0
# 1994         97209.0    8135.0         0.0   261669.0
# 1995        113557.0   10374.0         0.0   279367.0
# 1996        127640.0   13359.0         0.0   296417.0
# 1997        148059.0   19631.0         0.0   320125.0
# 1998        175115.0   26700.0         0.0   346293.0
# 1999        206461.0   35587.0         0.0   368844.0
# 2000        222330.0   36415.0         0.0   377314.0
# 2001        236303.0   39353.0       304.0   371881.0
# 2002        242144.0   33914.0       453.0   398628.0
# 2003        276279.0   43967.0      1050.0   437996.0
# 2004        323248.0   61166.0      1638.0   484689.0
# 2005        360194.0   82344.0      3253.0   519803.0
# 2006        396696.0   95784.0      3967.0   547765.0
# 2007        419495.0   99580.0      4826.0   560740.0
# 2008        386088.0   69142.0      4515.0   507340.0
# 2009        416691.0   77632.0      6247.0   502570.0
# 2010        453064.0  107503.0      8264.0   520016.0
# 2011        463794.0  119653.0      8944.0   493349.0
# 2012        498410.0  149782.0     10184.0   521253.0
# 2013        554298.0  198410.0     18545.0   558063.0
# 2014        611221.0  214253.0     25244.0   596781.0
# 2015        650483.0  218346.0     32554.0   617012.0
# 2016        694987.0  243135.0     40491.0   640076.0
# 2017        749584.0  315792.0     49507.0   657272.0
# 2018        755453.0  354087.0     54647.0   624483.0
# 2019        845135.0  438025.0     66314.0   668936.0
# 2020        964170.0  512071.0     75702.0   772956.0
# 2021       1073538.0  630022.0    106241.0  1003616.0
# 2022       1063858.0  597063.0    108250.0   974303.0

# %%
wealth_gap_df.dtypes
# Out:
# Year (Q4)       int64
# BabyBoom      float64
# GenX          float64
# Millennial    float64
# Silent        float64
# dtype: object

# %%
wealth_gap_df.plot()
# Out:
# <Axes: xlabel='Year (Q4)'>
